# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

# %%
test_data_file = 'test.csv'
train_data_file = 'train.csv'

# %%
# load dataset
test_raw_pd  = pd.read_csv(test_data_file)
train_raw_pd = pd.read_csv(train_data_file)

# %%
train_raw_pd
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_raw_pd.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
train_raw_pd.shape, test_raw_pd.shape
# Out:
# ((614, 13), (362, 12))

# %%
train_raw_pd.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %% [markdown]
# ## Data preprocessing

# %%
# removing unnecessory columns for both train and test data set
train_raw_pd.drop(columns='Loan_ID', inplace=True)
test_raw_pd.drop (columns='Loan_ID', inplace=True)
train_raw_pd.columns, test_raw_pd.columns
# Out:
# (Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#         'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#         'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#        dtype='object'),
#  Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#         'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#         'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#        dtype='object'))

# %%
train_raw_pd.columns, test_raw_pd.columns
# Out:
# (Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#         'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#         'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#        dtype='object'),
#  Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#         'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#         'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#        dtype='object'))

# %%
train_raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
test_raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             351 non-null    object
#  1   Married            362 non-null    object
#  2   Dependents         353 non-null    object
#  3   Education          362 non-null    object
#  4   Self_Employed      339 non-null    object
#  5   ApplicantIncome    362 non-null    int64
#  6   CoapplicantIncome  362 non-null    int64
#  7   LoanAmount         362 non-null    int64
#  8   Loan_Amount_Term   356 non-null    float64
#  9   Credit_History     333 non-null    float64
#  10  Property_Area      362 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 31.2+ KB

# %%
train_raw_pd.isna().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Droping NA values
train_raw_pd.dropna(axis=0,inplace=True)

# %%
train_raw_pd
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
train_raw_pd
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
# checking for duplicate values
train_raw_pd.duplicated().sum()
# Out:
# 0

# %%
# in case of duplicate values
train_raw_pd.drop_duplicates(inplace=True)
train_raw_pd.duplicated().sum()
train_raw_pd.shape
# Out:
# (480, 12)

# %%
# train_raw_pd.index = range(train_raw_pd.shape[0])
train_raw_pd.reset_index(drop=True, inplace=True)

# %%
train_raw_pd
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male     Yes          1      Graduate            No             4583
# 1      Male     Yes          0      Graduate           Yes             3000
# 2      Male     Yes          0  Not Graduate            No             2583
# 3      Male      No          0      Graduate            No             6000
# 4      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 475  Female      No          0      Graduate            No             2900
# 476    Male     Yes         3+      Graduate            No             4106
# 477    Male     Yes          1      Graduate            No             8072
# 478    Male     Yes          2      Graduate            No             7583
# 479  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
train_df = train_raw_pd[:]

# %%
object_columns = train_df.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
int_columns = train_df.select_dtypes(include=['int64', "float"]).columns
int_columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
train_df['Property_Area'].unique()
# Out:
# array(['Rural', 'Urban', 'Semiurban'], dtype=object)

# %%
# label encoding of catagoriacl and object data
train_df_encoded = pd.DataFrame()
for col in object_columns:
    le = LabelEncoder()
    le.fit(train_df[col])
    train_df_encoded[col] = le.transform(train_df[col])

# %%
train_df_encoded
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Property_Area  \
# 0         1        1           1          0              0              0
# 1         1        1           0          0              1              2
# 2         1        1           0          1              0              2
# 3         1        0           0          0              0              2
# 4         1        1           2          0              1              2
# ..      ...      ...         ...        ...            ...            ...
# 475       0        0           0          0              0              0
# 476       1        1           3          0              0              0
# 477       1        1           1          0              0              2
# 478       1        1           2          0              0              2
# 479       0        0           0          0              1              1
#
#      Loan_Status
# 0              0
# 1              1
# 2              1
# ...

# %%
train_df.shape ,  train_df_encoded.shape
# Out:
# ((480, 12), (480, 7))

# %%
train_df[object_columns] = train_df_encoded[object_columns]

# %%
train_df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1           1          0              0             4583
# 1         1        1           0          0              1             3000
# 2         1        1           0          1              0             2583
# 3         1        0           0          0              0             6000
# 4         1        1           2          0              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 475       0        0           0          0              0             2900
# 476       1        1           3          0              0             4106
# 477       1        1           1          0              0             8072
# 478       1        1           2          0              0             7583
# 479       0        0           0          0              1             4583
#
# ...

# %%
# Ready dataset for model fitting

# %%
df_for_BT = train_df[:]

# %%
# train binay tree ragressor using sk learn
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_for_BT, test_size=0.2)

# %%
train.shape, test.shape
# Out:
# ((384, 12), (96, 12))

# %%
train_y = train['Loan_Status']
train_x = train.drop(columns='Loan_Status')

test_x = test.drop(columns='Loan_Status')
test_y = test['Loan_Status']

# %%
tree = DecisionTreeRegressor()
tree.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()
